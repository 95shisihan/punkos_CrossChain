# %%
import argparse
from foundrycli import foundry_cli
import time
import json
import eth_account
from web3 import Web3
import os
import sys
sys.path.append("/Users/gyf/Desktop/myCross/HubChain1")
import sourcePlugin.BTC_Plugin as BTC_Plugin
import sourcePlugin.HUB_Plugin as HUB_Plugin

# %%
global source_name
source_name = 'Bitcoin Regtest'
def loadHub():
    """
    从配置文件中读取信息
    """
    with open('/Users/gyf/Desktop/myCross/HubChain1/managerClient/hubchainInfo.json','r') as result_file:
        save_dict = json.load(result_file)
    global target_rpc_url
    target_rpc_url = save_dict['HubchainManager']['rpc']
    mode = save_dict['HubchainManager']['mode']
    global multichain_contract_address
    multichain_contract_address = save_dict['HubchainManager']['address']
    global relay_contract_address
    relay_contract_address = save_dict[source_name]['relayContract']['address']
    global transport_contract_address
    transport_contract_address = save_dict[source_name]['transportContract']['address']
    with open('/Users/gyf/Desktop/myCross/HubChain1/relayerClient/BTC/configUser.json','r') as result_file:
        save_dict = json.load(result_file)
    global private_key
    private_key = save_dict['targetRPC']['relayerAccount'][mode]['private']
    save_dict['targetRPC']['mode'] = mode
    save_dict['targetRPC']['rpc'] = target_rpc_url
    data = json.dumps(save_dict, indent = 1)
    with open('/Users/gyf/Desktop/myCross/HubChain1/relayerClient/BTC/configUser.json','w',newline='\n') as result_file:
        result_file.write(data)
loadHub()

# %%
from bitcoinlib.services.bitcoind import *
from bitcoinlib.wallets import wallet_create_or_open
from bitcoinlib.services.services import Service
from pprint import pprint
from bitcoinlib.transactions import *
global rpc_connection
rpc_connection = BitcoindClient(base_url='http://bob:bob@localhost:18334').proxy

# %%
blockHeight = 50
txIndex = 0
testTxHash = BTC_Plugin.getRawTxFromIndex_RPC(rpc_connection,blockHeight,txIndex)
testTx = rpc_connection.getrawtransaction(testTxHash)

# %%
print(type(testTx))
# Out:
# <class 'str'>

# %%
def createTask(rawTx):
    res = HUB_Plugin.createTransportTask(transport_contract_address,target_rpc_url,private_key,rawTx)
    print(res)

# %%
createTask(testTx)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 createTask(testTx)
#
# Cell In[9], line 2, in createTask(rawTx)
#       1 def createTask(rawTx):
# ----> 2     res = HUB_Plugin.createTransportTask(transport_contract_address,target_rpc_url,private_key,rawTx)
#       3     print(res)
#
# File ~/Desktop/myCross/HubChain1/sourcePlugin/HUB_Plugin.py:107, in createTransportTask(transport_contract_address, target_rpc_url, private_key, rawTx)
#     100 def createTransportTask(transport_contract_address,target_rpc_url,private_key,rawTx):
#     101     """
#     102     向传输合约查询历史传输任务数量
#     103
#     104     返回值：
#     105     传输任务数量
#     106     """
# --> 107     res = foundry_cli(f'cast send {transport_contract_address} "createTask(bytes)" {rawTx} --rpc-url {target_rpc_url} --private-key {private_key} --gas-limit 999999' )
#     108     return(res)
#
# ...
